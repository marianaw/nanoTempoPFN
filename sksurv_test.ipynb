# %%
import numpy as np
from sksurv.datasets import load_gbsg2
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sksurv.metrics import integrated_brier_score
from sksurv.preprocessing import OneHotEncoder

# %%
X, y = load_gbsg2()
X["tgrade"] = X.loc[:, "tgrade"].map(len).astype(int)
Xt = OneHotEncoder().fit_transform(X)

# %%
type(y)
# Out:
# numpy.ndarray

# %%
type(y[0])
# Out:
# numpy.void

# %%
est = CoxPHSurvivalAnalysis(ties="efron").fit(Xt, y)

# %%
survs = est.predict_survival_function(Xt)
times = np.arange(365, 1826)
preds = np.asarray([[fn(t) for t in times] for fn in survs])

score = integrated_brier_score(y, y, preds, times)

# %%
preds.shape
# Out:
# (686, 1461)

# %%
times.shape
# Out:
# (1461,)

# %%
survs(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 survs(2)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
preds.shape
# Out:
# (686, 1461)

# %%
times.max()
# Out:
# np.int64(1825)

# %%
y[1]
# Out:
# np.void((True, 2018.0), dtype=[('cens', '?'), ('time', '<f8')])

# %%
times
# Out:
# array([ 365,  366,  367, ..., 1823, 1824, 1825])
